# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random

# %%
items = ["Hoodie", "Jeans", "Sneakers", "T-Shirt", "Jacket"]
brands = ["Nike", "Adidas", "Zara", "H&M", "Puma"]
conditions = ["New", "Good", "Worn"]
sources = ["Market", "Supplier", "Donation"]
customer_types = ["New", "Returning"]
payment_methods = ["Cash", "Mobile Money"]

# %%
data = []

for i in range(201):
    item = random.choice(items)
    brand = random.choice(brands)
    condition = random.choice(conditions)
    source = random.choice(sources)
    
    cost = round(random.uniform(5, 30), 2)
    
    markup = random.uniform(1.5, 3)
    selling_price = round(cost * markup, 2)
    
    discount = round(random.uniform(0, 5), 2)
    final_price = round(selling_price - discount, 2)
    
    profit = round(final_price - cost, 2)
    
    quantity = random.randint(1, 5)
    days_to_sell = random.randint(1, 30)
    
    date_sold = datetime.now() - timedelta(days=random.randint(0, 60))
    
    data.append([
        item, brand, condition, source,
        cost, selling_price, discount, final_price, profit,
        quantity, date_sold, days_to_sell,
        random.choice(customer_types),
        random.choice(payment_methods)
    ])

# %%
columns = [
    "item_name", "brand", "condition", "source",
    "cost", "selling_price", "discount", "final_price", "profit",
    "quantity", "date", "days_to_sell",
    "customer_type", "payment_method"
]

df = pd.DataFrame(data, columns=columns)

# %%
category_map = {
    "Hoodie": "Topwear",
    "T-Shirt": "Topwear",
    "Jeans": "Bottomwear",
    "Sneakers": "Footwear",
    "Jacket": "Outerwear"
}

df["category"] = df["item_name"].map(category_map)

# %%
df.head()
# Out:
#   item_name   brand condition    source   cost  selling_price  discount  \
# 0   T-Shirt  Adidas      Worn  Supplier  12.17          20.83      2.93
# 1     Jeans    Zara      Good  Supplier  18.79          49.59      3.21
# 2  Sneakers     H&M       New  Donation  29.48          80.71      2.68
# 3   T-Shirt    Zara      Worn  Donation  27.88          48.35      2.23
# 4  Sneakers  Adidas      Worn    Market  18.40          30.17      2.38
#
#    final_price  profit  quantity                       date  days_to_sell  \
# 0        17.90    5.73         4 2026-03-01 20:10:16.679363            25
# 1        46.38   27.59         4 2026-03-23 20:10:16.679401             8
# 2        78.03   48.55         3 2026-02-01 20:10:16.679420            18
# 3        46.12   18.24         2 2026-03-23 20:10:16.679435             6
# 4        27.79    9.39         3 2026-02-09 20:10:16.679450            21
#
#   customer_type payment_method    category
# 0           New           Cash     Topwear
# 1     Returning   Mobile Money  Bottomwear
# 2           New           Cash    Footwear
# 3           New           Cash     Topwear
# 4     Returning           Cash    Footwear

# %%
df.to_csv('../data/raw/thrift_data.csv')
