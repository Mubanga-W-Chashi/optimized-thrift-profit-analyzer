# %%
import pandas as pd

df = pd.read_csv('../data/raw/thrift_data.csv')
df.head()
# Out:
#    Unnamed: 0 item_name   brand condition    source   cost  selling_price  \
# 0           0   T-Shirt    Nike       New  Donation   8.92          23.41
# 1           1  Sneakers    Zara       New  Donation   7.55          20.69
# 2           2    Hoodie    Zara      Good  Donation  13.02          32.61
# 3           3     Jeans  Adidas       New    Market  12.61          21.54
# 4           4  Sneakers     H&M       New    Market  10.76          21.52
#
#    discount  final_price  profit  quantity                        date  \
# 0      4.83        18.58    9.66         1  2026-03-12 21:35:36.579343
# 1      2.83        17.86   10.31         2  2026-02-08 21:35:36.579407
# 2      0.85        31.76   18.74         4  2026-03-22 21:35:36.579438
# 3      3.20        18.34    5.73         2  2026-03-24 21:35:36.579461
# 4      1.24        20.28    9.52         5  2026-03-29 21:35:36.579484
#
#    days_to_sell customer_type payment_method    category
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      200 non-null    int64
#  1   item_name       200 non-null    str
#  2   brand           200 non-null    str
#  3   condition       200 non-null    str
#  4   source          200 non-null    str
#  5   cost            200 non-null    float64
#  6   selling_price   200 non-null    float64
#  7   discount        200 non-null    float64
#  8   final_price     200 non-null    float64
#  9   profit          200 non-null    float64
#  10  quantity        200 non-null    int64
#  11  date            200 non-null    str
#  12  days_to_sell    200 non-null    int64
#  13  customer_type   200 non-null    str
#  14  payment_method  200 non-null    str
#  15  category        200 non-null    str
# dtypes: float64(5), int64(3), str(8)
# memory usage: 25.1 KB
# ...
