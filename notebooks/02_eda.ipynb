# %%
import pandas as pd

df = pd.read_csv('../data/raw/thrift_data.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv('../data/raw/thrift_data.csv')
#       4 df.head()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py:56
#      46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#    (...)     52     options,
#      53 )
#      55 # let init-time option registration happen
# ---> 56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#    (...)    119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\config_init.py:31
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      200 non-null    int64
#  1   item_name       200 non-null    str
#  2   brand           200 non-null    str
#  3   item_condition  200 non-null    str
#  4   source          200 non-null    str
#  5   cost            200 non-null    float64
#  6   selling_price   200 non-null    float64
#  7   discount        200 non-null    float64
#  8   final_price     200 non-null    float64
#  9   profit          200 non-null    float64
#  10  quantity        200 non-null    int64
#  11  date            200 non-null    str
#  12  days_to_sell    200 non-null    int64
#  13  customer_type   200 non-null    str
#  14  payment_method  200 non-null    str
#  15  category        200 non-null    str
# dtypes: float64(5), int64(3), str(8)
# memory usage: 25.1 KB
# ...

# %%
# total revnue per row
df['revenue'] = df['final_price'] * df['quantity']

# total cost
df['total_cost'] = df['cost'] * df['quantity']

# total profit
df['total_profit'] = df['profit'] * df['quantity']

# %%
# Core Business questions:
# 1) Which category makes the most profit?
df.groupby('category')['total_profit'].sum().sort_values(ascending=False)

# 2) Which items sell fastest?
df.groupby('item_name')['days_to_sell'].mean().sort_values()

# 3) Which source is most profitable?
df.groupby('source')['total_profit'].sum().sort_values(ascending=False)

# 4) Which brand performs best?
df.groupby('brand')['total_profit'].sum().sort_values(ascending=False)

# 5) What customer behavior is observed?
df.groupby('customer_type')['total_profit'].sum()
# Are returning customers worth more?

# 6) What is the customer payment behaviour?
df.groupby("payment_method")["total_profit"].sum()

df.head()
# Out:
#    Unnamed: 0 item_name brand item_condition    source   cost  selling_price  \
# 0           0  Sneakers  Nike           Good  Supplier  26.87          40.47
# 1           1   T-Shirt  Nike           Worn  Donation   6.06          11.51
# 2           2     Jeans   H&M            New  Supplier  16.01          37.68
# 3           3    Hoodie  Zara           Worn  Supplier   5.10           8.09
# 4           4    Hoodie   H&M           Good    Market  10.21          16.25
#
#    discount  final_price  profit  quantity                        date  \
# 0      2.88        37.59   10.72         4  2026-03-09 13:52:38.130835
# 1      1.50        10.01    3.95         4  2026-04-02 13:52:38.130893
# 2      1.16        36.52   20.51         3  2026-02-21 13:52:38.130920
# 3      0.55         7.54    2.44         4  2026-03-10 13:52:38.130945
# 4      0.68        15.57    5.36         1  2026-03-13 13:52:38.131000
#
# ...

# %%
df[df['days_to_sell'] > 20]
# Out:
#      Unnamed: 0 item_name   brand item_condition    source   cost  \
# 3             3    Hoodie    Zara           Worn  Supplier   5.10
# 7             7    Jacket    Puma           Worn  Supplier  17.76
# 10           10   T-Shirt    Nike            New  Supplier  17.21
# 12           12    Jacket    Nike           Worn    Market  22.35
# 14           14    Hoodie  Adidas           Good    Market  26.84
# ..          ...       ...     ...            ...       ...    ...
# 183         183    Hoodie    Nike            New    Market  14.54
# 185         185   T-Shirt  Adidas           Worn  Donation  11.85
# 186         186  Sneakers     H&M           Good  Supplier  16.42
# 190         190    Jacket    Nike           Good  Donation  24.85
# 196         196    Jacket    Nike           Worn  Donation   9.97
#
#      selling_price  discount  final_price  profit  quantity  \
# 3             8.09      0.55         7.54    2.44         4
# ...

# %%
df[df["profit"] < 5]
# Out:
#      Unnamed: 0 item_name   brand item_condition    source   cost  \
# 1             1   T-Shirt    Nike           Worn  Donation   6.06
# 3             3    Hoodie    Zara           Worn  Supplier   5.10
# 9             9  Sneakers    Zara            New    Market  10.16
# 11           11    Hoodie  Adidas           Worn    Market  12.08
# 13           13    Jacket    Puma           Good  Supplier  14.28
# 29           29    Jacket    Nike           Worn  Donation   5.25
# 58           58    Jacket  Adidas            New  Donation   9.20
# 61           61     Jeans    Zara            New  Donation   5.87
# 77           77     Jeans    Zara            New    Market  10.49
# 94           94     Jeans     H&M            New    Market   6.33
# 100         100   T-Shirt    Puma           Good  Donation   7.84
# 119         119  Sneakers     H&M           Good  Donation   5.22
# 129         129     Jeans    Nike           Worn  Donation   5.09
# ...

# %%
df[df['revnenue']]
